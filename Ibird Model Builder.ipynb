# %%
from fastbook import *

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0AE2-FB83
#
#  Directory of C:\Users\amitk\OneDrive\ml\projects\ibird
#
# 20-06-2023  15:23    <DIR>          .
# 20-06-2023  09:04    <DIR>          ..
# 20-06-2023  14:06    <DIR>          .ipynb_checkpoints
# 16-06-2023  14:45           105,694 Bird Dataset Builder.ipynb
# 20-06-2023  15:23             3,126 Ibird Model Builder.ipynb
# 16-06-2023  08:27            23,833 ibird.csv
#                3 File(s)        132,653 bytes
#                3 Dir(s)  77,958,410,240 bytes free

# %%
path = Path('D:/ibirds')
print(path)

fns = get_image_files(path)
print(fns)
# Out:
# D:\ibirds
# ...

# %%
failed = verify_images(fns)
failed

# %%
??get_image_files
